# %%
import pandas as pd 
import numpy as np

# %%
pd.pandas.set_option('display.max_columns', None)

# %%
train = pd.read_csv(r'C:\Users\user\Desktop\train.csv')
test = pd.read_csv(r'C:\Users\user\Desktop\test.csv')

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# distribution comparison
numerical_features = [col for col in train.columns if train[col].dtypes != 'O']
discrete_features = [col for col in numerical_features if len(train[col].unique()) < 25 and col not in ['Id']]
continuous_features = [feature for feature in numerical_features if feature not in discrete_features+['Id']]
categorical_features = [col for col in train.columns if train[col].dtype == 'O']

# %%
print("Total Number of Numerical Columns : ",len(numerical_features))
print("Number of discrete features : ",len(discrete_features))
print("No of continuous features are : ", len(continuous_features))
print("Number of categorical features : ",len(categorical_features))
# Out:
# Total Number of Numerical Columns :  38
# Number of discrete features :  18
# No of continuous features are :  19
# Number of categorical features :  43

# %%
sns.set_style('darkgrid')
fig = plt.figure(figsize = (15,68))
for i in range(len(discrete_features)):
    column = discrete_features[i]
    sub = fig.add_subplot(22,2,i+1)
    plot = sns.barplot(data =train,x = column , y = 'SalePrice')

# %%
sns.set_style('darkgrid')
fig = plt.figure(figsize = (15,36))
for i in range(len(discrete_features)):
    column = discrete_features[i]
    sub = fig.add_subplot(10,4,i+1)
    plot = sns.countplot(data =train,x = column)

# %%
sns.set_style('darkgrid')
fig = plt.figure(figsize = (15,30))
for i in range(len(continuous_features)):
    column = continuous_features[i]
    sub = fig.add_subplot(10,4,i+1)
    plot = sns.histplot(data =train,x = column,color = 'brown')

# %%
sns.set_style('darkgrid')
fig = plt.figure(figsize = (16,72))
for i in range(len(categorical_features)):
    column = categorical_features[i]
    sub = fig.add_subplot(22,2,i+1)
    plot = sns.countplot(data =train,x = column)

# %%
sns.set(font_scale = 0.8)
sns.set_style('darkgrid')
fig = plt.figure(figsize = (14,30))
for i in range(len(continuous_features)):
    column = continuous_features[i]
    sub = fig.add_subplot(10,4,i+1)
    plot = sns.boxplot(data = train, y = column,color = 'orange')

# %%
def facetgrid_boxplot(x, y, **kwargs):
    sns.boxplot(x=x, y=y)
    x=plt.xticks(rotation=90)
    
categorical = train.select_dtypes(exclude=['int64','float64'])
f = pd.melt(df, id_vars=['SalePrice'], value_vars=sorted(train[categorical.columns]))
g = sns.FacetGrid(f, col="variable", col_wrap=3, sharex=False, sharey=False, size=5)
g = g.map(facetgrid_boxplot, "value", "SalePrice")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# linearity check 
numeric_features = [col for col in train.columns if train[col].dtypes != 'O']
fig = plt.figure(figsize = (17,42))
for i in range(len(numeric_features)):
    column = numeric_features[i]
    sub = fig.add_subplot(10,4,i+1)
    plot = sns.scatterplot(data = train,x = column,y = 'SalePrice',hue = 'SalePrice')

# %%
categorical_features = [col for col in train.columns if train[col].dtype == 'O']

# %%
train[categorical_features]
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
sns.set_style('darkgrid')
unique_values = []
for col in train[categorical_features]:
     unique_values.append(train[categorical_features][col].unique().size)
plt.figure(figsize=(16,6))
plt.title('No. Unique values of Categorical Features')
plt.xticks(rotation=90)
sns.barplot(x = train[categorical_features].columns,y=unique_values,palette = 'rocket')
# Out:
# <AxesSubplot:title={'center':'No. Unique values of Categorical Features'}>

# %%
# temporal varibale 
year_feature = [col for col in train.columns if 'Yr' in col or 'Year' in col]
print(year_feature)
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
train.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('House Price')
plt.title('House price vs YearSold')
# Out:
# Text(0.5, 1.0, 'House price vs YearSold')

# %%
for feature in year_feature:
    print(feature,train[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
for feature in year_feature:
    if feature!='YrSold':
        ## We will capture the difference between year variable and year the house was sold for
        df[feature]=train['YrSold']-train[feature]
        plt.scatter(train[feature],train['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %%
training_corr = train.corr(method='spearman')
plt.figure(figsize=(20,10))
sns.heatmap(training_corr, cmap="YlGnBu", linewidths=.5)
# Out:
# <AxesSubplot:>

# %%
train.dtypes.value_counts()
# Out:
# object     43
# int64      35
# float64     3
# dtype: int64

# %%
test.dtypes.value_counts()
# Out:
# object     43
# int64      26
# float64    11
# dtype: int64

# %%
# null values
train.isnull().sum().sort_values(ascending = False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Id                 0
# dtype: int64

# %%
import missingno as msno
msno.heatmap(train)
# Out:
# <AxesSubplot:>

# %%
#test data comparison
test.isnull().sum().sort_values(ascending = False).head(20)
# Out:
# PoolQC          1456
# MiscFeature     1408
# Alley           1352
# Fence           1169
# FireplaceQu      730
# LotFrontage      227
# GarageYrBlt       78
# GarageQual        78
# GarageFinish      78
# GarageCond        78
# GarageType        76
# BsmtCond          45
# BsmtQual          44
# BsmtExposure      44
# BsmtFinType1      42
# BsmtFinType2      42
# MasVnrType        16
# MasVnrArea        15
# MSZoning           4
# BsmtHalfBath       2
# dtype: int64

# %%
msno.heatmap(test)
# Out:
# <AxesSubplot:>

# %%
# null value comparison
null_train = train.isnull().sum()
null_test = test.isnull().sum()
null_train = null_train.drop('SalePrice')
null_comp_df = null_train.compare(null_test).sort_values(['self'],ascending = [False])
null_comp_df
# Out:
#                 self   other
# PoolQC        1453.0  1456.0
# MiscFeature   1406.0  1408.0
# Alley         1369.0  1352.0
# Fence         1179.0  1169.0
# FireplaceQu    690.0   730.0
# LotFrontage    259.0   227.0
# GarageType      81.0    76.0
# GarageCond      81.0    78.0
# GarageYrBlt     81.0    78.0
# GarageFinish    81.0    78.0
# GarageQual      81.0    78.0
# BsmtFinType2    38.0    42.0
# BsmtExposure    38.0    44.0
# BsmtFinType1    37.0    42.0
# BsmtCond        37.0    45.0
# BsmtQual        37.0    44.0
# MasVnrArea       8.0    15.0
# MasVnrType       8.0    16.0
# Electrical       1.0     0.0
# GarageArea       0.0     1.0
# GarageCars       0.0     1.0
# MSZoning         0.0     4.0
# Functional       0.0     2.0
# KitchenQual      0.0     1.0
# BsmtHalfBath     0.0     2.0
# BsmtFullBath     0.0     2.0
# TotalBsmtSF      0.0     1.0
# BsmtUnfSF        0.0     1.0
# BsmtFinSF2       0.0     1.0
# BsmtFinSF1       0.0     1.0
# Exterior2nd      0.0     1.0
# ...

# %%
#perentage of missing values in train dataset
percent_missing = train.isnull().sum()* 100 / len(train)
percent_missing.sort_values(ascending =False).iloc[:20]
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageYrBlt      5.547945
# GarageCond       5.547945
# GarageType       5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# BsmtFinType2     2.602740
# BsmtExposure     2.602740
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtFinType1     2.534247
# MasVnrArea       0.547945
# MasVnrType       0.547945
# Electrical       0.068493
# Id               0.000000
# dtype: float64

# %%
# percentage of missing values in test data
percent_missing = test.isnull().sum()* 100 / len(test)
percent_missing.sort_values(ascending =False).iloc[:20]
# Out:
# PoolQC          99.794380
# MiscFeature     96.504455
# Alley           92.666210
# Fence           80.123372
# FireplaceQu     50.034270
# LotFrontage     15.558602
# GarageYrBlt      5.346127
# GarageQual       5.346127
# GarageFinish     5.346127
# GarageCond       5.346127
# GarageType       5.209047
# BsmtCond         3.084304
# BsmtQual         3.015764
# BsmtExposure     3.015764
# BsmtFinType1     2.878684
# BsmtFinType2     2.878684
# MasVnrType       1.096642
# MasVnrArea       1.028101
# MSZoning         0.274160
# BsmtHalfBath     0.137080
# dtype: float64

# %%
def filter(dataset):
    n = len(dataset)
    features = []
    for col in dataset.columns:
        if( dataset[col].isnull().sum()>=int(n*0.2)): #taking 0.2 as ratio any attribute having more null values than 20% of total data is discarded
            features.append(col)
    print(features,"features removed from provided data")
    dataset.drop(features,axis=1,inplace=True)
    return dataset

# %%
print("Number of columns before dropping : ",len(train.columns))
print("Number of columns before dropping : ",len(test.columns))
# Out:
# Number of columns before dropping :  81
# Number of columns before dropping :  80

# %%
train_data = filter(train)
test_data = filter(test)
print("Number of columns after dropping : ",len(train_data.columns))
print("Number of columns after dropping : ",len(test_data.columns))
# Out:
# ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'] features removed from provided data
# ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'] features removed from provided data
# Number of columns after dropping :  76
# Number of columns after dropping :  75

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
def filter1(dataset):
    for col in dataset.columns:
        #print(dataset[col].dtypes)
        if dataset[col].dtypes=='object':
            dataset[col].fillna(dataset[col].mode()[0],inplace=True)
        elif dataset[col].dtypes=='int64' or dataset[col].dtypes=='float64':
            dataset[col].fillna(dataset[col].mean(),inplace=True)            

    return dataset

# %%
train_data = filter1(train_data)
test_data = filter1(test_data)

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (12,6))
sns.heatmap(train_data.isnull())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (12,6))
sns.heatmap(test_data.isnull())
# Out:
# <AxesSubplot:>

# %%
# skewness test
numeric_train = train_data.dtypes[train_data.dtypes != 'object'].index
numeric_test = test_data.dtypes[test_data.dtypes != 'object'].index

from scipy.stats import norm, skew
skewed_feats = train_data[numeric_train].apply(lambda x : skew(x))
skewed_feats_test = test_data[numeric_test].apply(lambda x : skew(x))

# %%
skewed_feats.sort_values(ascending  =False)
# Out:
# MiscVal          24.451640
# PoolArea         14.813135
# LotArea          12.195142
# 3SsnPorch        10.293752
# LowQualFinSF      9.002080
# KitchenAbvGr      4.483784
# BsmtFinSF2        4.250888
# ScreenPorch       4.117977
# BsmtHalfBath      4.099186
# EnclosedPorch     3.086696
# MasVnrArea        2.673661
# LotFrontage       2.382499
# OpenPorchSF       2.361912
# SalePrice         1.880941
# BsmtFinSF1        1.683771
# WoodDeckSF        1.539792
# TotalBsmtSF       1.522688
# MSSubClass        1.406210
# 1stFlrSF          1.375342
# GrLivArea         1.365156
# BsmtUnfSF         0.919323
# 2ndFlrSF          0.812194
# OverallCond       0.692355
# TotRmsAbvGrd      0.675646
# HalfBath          0.675203
# Fireplaces        0.648898
# BsmtFullBath      0.595454
# OverallQual       0.216721
# MoSold            0.211835
# BedroomAbvGr      0.211572
# GarageArea        0.179796
# YrSold            0.096170
# FullBath          0.036524
# Id                0.000000
# ...

# %%
skewed_feats_test.sort_values(ascending  =False)
# Out:
# PoolArea         20.176117
# MiscVal          20.054543
# LowQualFinSF     16.150628
# 3SsnPorch        12.511336
# EnclosedPorch     4.664371
# KitchenAbvGr      4.074860
# BsmtFinSF2        4.038570
# ScreenPorch       3.784349
# BsmtHalfBath      3.778564
# LotArea           3.112013
# OpenPorchSF       2.685015
# MasVnrArea        2.543855
# WoodDeckSF        2.128569
# 1stFlrSF          1.556592
# MSSubClass        1.345305
# BsmtFinSF1        1.164876
# GrLivArea         1.129240
# BsmtUnfSF         0.919285
# 2ndFlrSF          0.911944
# TotRmsAbvGrd      0.841731
# Fireplaces        0.819015
# TotalBsmtSF       0.813031
# LotFrontage       0.719448
# HalfBath          0.713993
# BsmtFullBath      0.649474
# OverallCond       0.448703
# BedroomAbvGr      0.436174
# GarageArea        0.300033
# FullBath          0.295534
# MoSold            0.182834
# OverallQual       0.181010
# YrSold            0.168813
# Id                0.000000
# GarageCars       -0.107068
# ...

# %%
log_list = skewed_feats[skewed_feats > 0.5].index
for col in log_list:
    train_data[col] = train_data[col].apply(lambda x:x+0.00001)
    train_data[[col]] = np.log(train_data[[col]])

# %%
log_test = skewed_feats_test[skewed_feats_test > 0.5].index
for col in log_test:
    test_data[col] = test_data[col].apply(lambda x:x+0.00001)
    test_data[[col]] = np.log(test_data[[col]])

# %%
train_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage   LotArea Street LotShape  \
# 0        1    4.094345       RL     4.174387  9.041922   Pave      Reg
# 1        2    2.995733       RL     4.382027  9.169518   Pave      Reg
# 2        3    4.094345       RL     4.219508  9.328123   Pave      IR1
# 3        4    4.248495       RL     4.094345  9.164296   Pave      IR1
# 4        5    4.094345       RL     4.430817  9.565214   Pave      IR1
# ...    ...         ...      ...          ...       ...    ...      ...
# 1455  1456    4.094345       RL     4.127135  8.976768   Pave      Reg
# 1456  1457    2.995733       RL     4.442651  9.486076   Pave      Reg
# 1457  1458    4.248495       RL     4.189655  9.109636   Pave      Reg
# 1458  1459    2.995733       RL     4.219508  9.181632   Pave      Reg
# 1459  1460    2.995733       RL     4.317488  9.204020   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
test_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage   LotArea Street LotShape  \
# 0     1461    2.995733       RH     4.382027  9.360655   Pave      Reg
# 1     1462    2.995733       RL     4.394449  9.565704   Pave      IR1
# 2     1463    4.094345       RL     4.304065  9.534595   Pave      IR1
# 3     1464    4.094345       RL     4.356709  9.208138   Pave      IR1
# 4     1465    4.787492       RL     3.761200  8.518193   Pave      IR1
# ...    ...         ...      ...          ...       ...    ...      ...
# 1454  2915    5.075174       RM     3.044523  7.568379   Pave      Reg
# 1455  2916    5.075174       RM     3.044523  7.546446   Pave      Reg
# 1456  2917    2.995733       RL     5.075174  9.903488   Pave      Reg
# 1457  2918    4.442651       RL     4.127135  9.253496   Pave      Reg
# 1458  2919    4.094345       RL     4.304065  9.172327   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
feature_scale = ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
       'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
       'MiscVal', 'MoSold', 'YrSold']
    
for c in feature_scale:
    if c in train_data.columns:
        scaler=MinMaxScaler()
        scaler.fit(train_data[feature_scale])

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street LotShape LandContour  \
# 0   1    4.094345       RL     4.174387  9.041922   Pave      Reg         Lvl
# 1   2    2.995733       RL     4.382027  9.169518   Pave      Reg         Lvl
# 2   3    4.094345       RL     4.219508  9.328123   Pave      IR1         Lvl
# 3   4    4.248495       RL     4.094345  9.164296   Pave      IR1         Lvl
# 4   5    4.094345       RL     4.430817  9.565214   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
feature_scale =['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
       'PavedDrive', 'SaleType', 'SaleCondition']

for c in feature_scale:
    if c in train_data.columns:
        lbl = LabelEncoder()
        lbl.fit(list(train_data[c].values))
        train_data[c] = lbl.transform(list(train_data[c].values))

# %%
train_data.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  \
# 0   1    4.094345         3     4.174387  9.041922       1         3
# 1   2    2.995733         3     4.382027  9.169518       1         3
# 2   3    4.094345         3     4.219508  9.328123       1         0
# 3   4    4.248495         3     4.094345  9.164296       1         0
# 4   5    4.094345         3     4.430817  9.565214       1         0
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            3          0          4          0             5           2
# 1            3          0          2          0            24           1
# 2            3          0          4          0             5           2
# 3            3          0          0          0             6           2
# 4            3          0          2          0            15           2
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# feature_scaling test data
feature_scale = ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
       'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
       'MiscVal', 'MoSold', 'YrSold']
    
for c in feature_scale:
    if c in test_data.columns:
        scaler=MinMaxScaler()
        scaler.fit(test_data[feature_scale])

# %%
feature_scale =['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
       'PavedDrive', 'SaleType', 'SaleCondition']

for c in feature_scale:
    if c in test_data.columns:
        lbl = LabelEncoder()
        lbl.fit(list(test_data[c].values))
        test_data[c] = lbl.transform(list(test_data[c].values))

# %%
test_data.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  \
# 0  1461    2.995733         2     4.382027  9.360655       1         3
# 1  1462    2.995733         3     4.394449  9.565704       1         0
# 2  1463    4.094345         3     4.304065  9.534595       1         0
# 3  1464    4.094345         3     4.356709  9.208138       1         0
# 4  1465    4.787492         3     3.761200  8.518193       1         0
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            3          0          4          0            12           1
# 1            3          0          0          0            12           2
# 2            3          0          4          0             8           2
# 3            3          0          4          0             8           2
# 4            1          0          4          0            22           2
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

# %%
y_train = train_data[['SalePrice']]

# %%
X_train= train_data.drop(['Id','SalePrice'],axis=1)

# %%
# feature selection model
feature_sel_model = SelectFromModel(Lasso(alpha=0.01, random_state=0)) # remember to set the seed, the random state in this function
feature_sel_model.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.01, random_state=0))

# %%
feature_sel_model.get_support()
# Out:
# array([False, False, False,  True, False,  True, False, False, False,
#        False,  True, False, False,  True,  True,  True, False,  True,
#         True, False, False,  True, False, False,  True, False, False,
#        False,  True, False, False, False,  True, False, False, False,
#         True, False,  True, False, False,  True,  True, False,  True,
#         True, False,  True,  True,  True, False,  True, False,  True,
#         True,  True,  True, False, False,  True, False, False, False,
#         True,  True, False,  True,  True, False,  True, False, False,
#        False,  True])

# %%
selected_feat = X_train.columns[(feature_sel_model.get_support())]

# %%
selected_feat
# Out:
# Index(['LotArea', 'LotShape', 'Neighborhood', 'BldgType', 'HouseStyle',
#        'OverallQual', 'YearBuilt', 'YearRemodAdd', 'Exterior1st', 'MasVnrArea',
#        'BsmtQual', 'BsmtFinSF1', 'TotalBsmtSF', 'HeatingQC', '1stFlrSF',
#        '2ndFlrSF', 'GrLivArea', 'BsmtFullBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenQual', 'Functional', 'Fireplaces', 'GarageType',
#        'GarageYrBlt', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', '3SsnPorch',
#        'ScreenPorch', 'MiscVal', 'SaleCondition'],
#       dtype='object')

# %%
train_data = train_data[selected_feat]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(train_data, y_train, test_size=0.3, random_state=101)

# %%
X_train
# Out:
#        LotArea  LotShape  Neighborhood  BldgType  HouseStyle  OverallQual  \
# 1312  9.166597         0            15         0           5            8
# 1408  8.954157         3            17         0           5            4
# 1165  9.163354         0            16         0           2            7
# 1346  9.941794         1            14         0           2            7
# 399   9.002701         3            21         0           5            7
# ...        ...       ...           ...       ...         ...          ...
# 1417  9.713839         0            15         0           5            8
# 75    7.375256         3            10         3           7            4
# 599   7.575585         3             1         3           5            6
# 1361  9.690171         0            22         0           2            7
# 863   8.978534         3            12         0           2            5
#
#       YearBuilt  YearRemodAdd  Exterior1st  MasVnrArea  BsmtQual  BsmtFinSF1  \
# ...

# %%
X_test
# Out:
#         LotArea  LotShape  Neighborhood  BldgType  HouseStyle  OverallQual  \
# 1054   9.338470         3             5         0           5            8
# 361    9.120853         3             3         0           0            5
# 1282   9.082507         0             5         0           2            5
# 161    9.524275         0            16         0           5            9
# 515    9.410829         3            16         0           2           10
# ...         ...       ...           ...       ...         ...          ...
# 249   11.976659         1             4         0           0            6
# 467    9.156940         3            12         0           5            5
# 650    9.002701         3            21         0           5            7
# 48     8.402007         3            17         1           5            4
# 454    9.137447         3            11         2           2            5
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
#linear Regression
lr = LinearRegression()
lr.fit(X_train, y_train)
y_train_pred = lr.predict(X_test)

# %%
y_train_pred
# Out:
# array([12.43546518, 11.86483696, 11.88945111, 12.83528033, 12.90632143,
#        11.67833936, 11.82485714, 11.86824219, 11.88542098, 11.88032086,
#        11.64682498, 11.84871854, 11.74594792, 12.04031468, 11.95456408,
#        12.02520664, 11.87724937, 11.66523543, 11.90251485, 12.27722205,
#        11.93607338, 11.36006788, 12.14493455, 11.90592652, 12.30022462,
#        11.8818108 , 11.57582138, 12.09762429, 12.14515072, 11.60981717,
#        12.24939788, 11.97918717, 12.05214369, 12.51806724, 11.01197924,
#        11.46032622, 12.98506014, 12.27738434, 11.63831931, 11.38874419,
#        12.41154223, 12.11462284, 12.28207466, 12.09677964, 11.66198892,
#        11.77079303, 12.68126582, 12.15000314, 11.76075264, 11.66294514,
#        11.71557564, 12.45471733, 11.70972841, 11.94913631, 12.10366612,
#        11.77170329, 12.14009908, 12.37969409, 12.03321579, 12.36187542,
#        12.22634224, 11.97147776, 11.73598553, 11.5002484 , 11.68192149,
# ...

# %%
lr.coef_
# Out:
# array([[ 8.50767910e-02, -5.09866489e-03,  1.46340358e-04,
#         -9.63117637e-03,  1.09286985e-03,  7.68695221e-02,
#          1.94171122e-03,  1.65720590e-03, -1.86939700e-03,
#         -1.03627319e-04, -1.88496331e-02,  4.81810236e-03,
#          4.69201868e-03, -9.05544371e-03,  9.07816406e-02,
#         -9.45704242e-04,  3.52415466e-01,  2.19426143e-03,
#          1.76566707e-02,  2.04016512e-03, -9.42162005e-03,
#         -3.10224763e-02,  2.89410215e-02,  2.70644562e-03,
#          3.30483449e-03, -6.92216157e-04,  1.66267885e-04,
#          1.16887066e-03,  1.67505692e-04,  9.41816490e-04,
#          2.91744003e-03, -1.12971174e-03,  2.50091722e-02]])

# %%
coef = pd.DataFrame(data = lr.coef_ , columns = X_train.columns , index = ['coefficients'])

# %%
coef
# Out:
#                LotArea  LotShape  Neighborhood  BldgType  HouseStyle  \
# coefficients  0.085077 -0.005099      0.000146 -0.009631    0.001093
#
#               OverallQual  YearBuilt  YearRemodAdd  Exterior1st  MasVnrArea  \
# coefficients      0.07687   0.001942      0.001657    -0.001869   -0.000104
#
#               BsmtQual  BsmtFinSF1  TotalBsmtSF  HeatingQC  1stFlrSF  \
# coefficients  -0.01885    0.004818     0.004692  -0.009055  0.090782
#
#               2ndFlrSF  GrLivArea  BsmtFullBath  FullBath  HalfBath  \
# coefficients -0.000946   0.352415      0.002194  0.017657   0.00204
#
#               BedroomAbvGr  KitchenQual  Functional  Fireplaces  GarageType  \
# coefficients     -0.009422    -0.031022    0.028941    0.002706    0.003305
#
#               GarageYrBlt  GarageArea  WoodDeckSF  OpenPorchSF  3SsnPorch  \
# coefficients    -0.000692    0.000166    0.001169     0.000168   0.000942
#
#               ScreenPorch  MiscVal  SaleCondition
# ...

# %%
print(mean_squared_error(y_test, y_train_pred))
# Out:
# 0.02005120528768259

# %%
#gradient Boosting regression 
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
gbr = GradientBoostingRegressor(random_state=0)
param_grid = {'n_estimators': [2500],
              'max_features': [13],
              'max_depth': [5],
              'learning_rate': [0.05],
              'subsample': [0.8],
             'random_state' : [5]}
                              
gb_model = GridSearchCV(estimator=gbr, param_grid=param_grid, n_jobs=1, cv=5)
gb_model.fit(X_train,y_train)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:570: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:570: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:570: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
y_train_pred = gb_model.predict(X_test)
print(mean_squared_error(y_test, y_train_pred))
# Out:
# 0.02005120528768259

# %%
#xgboost
import xgboost as xgb
xgbreg = xgb.XGBRegressor(seed=0)
param_grid2 = {'n_estimators': [2000], 
              'learning_rate': [0.05],
              'max_depth': [3, 7],
              'subsample': [0.8],
              'colsample_bytree': [0.45, 0.75]}
    
xgb_model = GridSearchCV(estimator=xgbreg, param_grid=param_grid2, n_jobs=1, cv=10)
xgb_model.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None,...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
# ...

# %%
Y_pred = xgb_model.predict(X_test)
print(mean_squared_error(y_test, y_train_pred))
# Out:
# 0.02005120528768259

# %%
#random forest Regressor
from sklearn.ensemble import RandomForestRegressor
model_RFR = RandomForestRegressor()
model_RFR.fit(X_train, y_train)
Y_pred = model_RFR.predict(X_test)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_1224/2191614146.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_RFR.fit(X_train, y_train)

# %%
print(mean_squared_error(y_test, Y_pred))
# Out:
# 0.025062603447920166
